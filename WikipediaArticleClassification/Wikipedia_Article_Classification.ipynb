# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/articleDesc.csv", sep = '[@$@]', engine='python', error_bad_lines=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Skipping line 388779: Expected 19 fields in line 388779, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 572874: Expected 19 fields in line 572874, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 684635: Expected 19 fields in line 684635, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 889832: Expected 19 fields in line 889832, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 1298564: Expected 19 fields in line 1298564, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 1409973: Expected 19 fields in line 1409973, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 3148941: Expected 19 fields in line 3148941, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 3762202: Expected 19 fields in line 3762202, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 4267943: Expected 19 fields in line 4267943, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 4371405: Expected 19 fields in line 4371405, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 4764036: Expected 19 fields in line 4764036, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 5709438: Expected 19 fields in line 5709438, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 5988652: Expected 19 fields in line 5988652, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 6045341: Expected 19 fields in line 6045341, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.

# %%
df
# Out:
#                                           Article Name Unnamed: 1 Unnamed: 2  \
# 0        Population_history_of_ancient_Egypt_Archive_8        NaN        NaN
# 1                                      Sin_Mirar_Atrás        NaN        NaN
# 2                                                RMWFC        NaN        NaN
# 3                                     Wilbur_E._Colyer        NaN        NaN
# 4                                          Salmson_B.9        NaN        NaN
# ...                                                ...        ...        ...
# 6153232                               I_Wanna_Hold_You        NaN        NaN
# 6153233                         Setback_(architecture)        NaN        NaN
# 6153234         China_and_the_World_Trade_Organization        NaN        NaN
# 6153235                         Jan_de_Vries_(athlete)        NaN        NaN
# 6153236                          Bill_White_(baseball)        NaN        NaN
#
#         Vital Article Unnamed: 4  Unnamed: 5 Level  Unnamed: 7  Unnamed: 8  \
# 0                 NaN        NaN         NaN   NaN         NaN         NaN
# 1                 NaN        NaN         NaN   NaN         NaN         NaN
# 2                 NaN        NaN         NaN   NaN         NaN         NaN
# 3                 NaN        NaN         NaN   NaN         NaN         NaN
# 4                 NaN        NaN         NaN   NaN         NaN         NaN
# ...               ...        ...         ...   ...         ...         ...
# 6153232           NaN        NaN         NaN   NaN         NaN         NaN
# 6153233           NaN        NaN         NaN   NaN         NaN         NaN
# 6153234           NaN        NaN         NaN   NaN         NaN         NaN
# 6153235           NaN        NaN         NaN   NaN         NaN         NaN
# 6153236           NaN        NaN         NaN   NaN         NaN         NaN
#
#          Class Unnamed: 10 Unnamed: 11 Importance Unnamed: 13  Unnamed: 14  \
# 0          NaN         NaN         NaN        NaN         NaN          NaN
# 1          NaN         NaN         NaN        NaN         NaN          NaN
# 2          NaN         NaN         NaN        NaN         NaN          NaN
# 3         Stub         NaN         NaN        NaN         NaN          NaN
# 4        Start         NaN         NaN        NaN         NaN          NaN
# ...        ...         ...         ...        ...         ...          ...
# 6153232   Stub         NaN         NaN        NaN         NaN          NaN
# 6153233    NaN         NaN         NaN        NaN         NaN          NaN
# 6153234  Start         NaN         NaN        NaN         NaN          NaN
# 6153235   Stub         NaN         NaN        NaN         NaN          NaN
# 6153236    NaN         NaN         NaN        NaN         NaN          NaN
#
#                                                      Topic Unnamed: 16  \
# 0                                                      NaN        None
# 1                                                      NaN        None
# 2                                                      NaN        None
# 3        ['biography', 'military history', 'united stat...        None
# 4                                                      NaN        None
# ...                                                    ...         ...
# 6153232                                                 []        None
# 6153233     ['architecture', 'urban studies and planning']        None
# 6153234                                          ['china']        None
# 6153235  ['running', 'olympics', 'biography', 'netherla...        None
# 6153236                                                NaN        None
#
#         Unnamed: 17  Wikiproject
# 0              None          NaN
# 1              None          NaN
# 2              None          NaN
# 3              None          NaN
# 4              None          NaN
# ...             ...          ...
# 6153232        None          NaN
# 6153233        None          NaN
# 6153234        None          NaN
# 6153235        None          NaN
# 6153236        None          NaN
#
# [6153237 rows x 19 columns]

# %%
df=df[["Article Name","Vital Article","Importance","Topic","Wikiproject","Class","Level"]]

# %%
df
# Out:
#                                           Article Name Vital Article  \
# 0        Population_history_of_ancient_Egypt_Archive_8           NaN
# 1                                      Sin_Mirar_Atrás           NaN
# 2                                                RMWFC           NaN
# 3                                     Wilbur_E._Colyer           NaN
# 4                                          Salmson_B.9           NaN
# ...                                                ...           ...
# 6153232                               I_Wanna_Hold_You           NaN
# 6153233                         Setback_(architecture)           NaN
# 6153234         China_and_the_World_Trade_Organization           NaN
# 6153235                         Jan_de_Vries_(athlete)           NaN
# 6153236                          Bill_White_(baseball)           NaN
#
#         Importance                                              Topic  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN  ['biography', 'military history', 'united stat...
# 4              NaN                                                NaN
# ...            ...                                                ...
# 6153232        NaN                                                 []
# 6153233        NaN     ['architecture', 'urban studies and planning']
# 6153234        NaN                                          ['china']
# 6153235        NaN  ['running', 'olympics', 'biography', 'netherla...
# 6153236        NaN                                                NaN
#
#          Wikiproject  Class Level
# 0                NaN    NaN   NaN
# 1                NaN    NaN   NaN
# 2                NaN    NaN   NaN
# 3                NaN   Stub   NaN
# 4                NaN  Start   NaN
# ...              ...    ...   ...
# 6153232          NaN   Stub   NaN
# 6153233          NaN    NaN   NaN
# 6153234          NaN  Start   NaN
# 6153235          NaN   Stub   NaN
# 6153236          NaN    NaN   NaN
#
# [6153237 rows x 7 columns]

# %%
df.nunique()
# Out:
# Article Name     6152920
# Vital Article          1
# Importance            70
# Topic             548972
# Wikiproject            0
# Class                190
# Level                 22
# dtype: int64

# %%
df1=df.drop(["Vital Article","Wikiproject"],axis=1)

# %%
df2=df1[~df1.Class.isnull()]

# %%
df2.shape
# Out:
# (4312408, 5)

# %%
df2.Class.apply(lambda x:1 if x=='FA' else 0)
# Out:
# 3          0
# 4          0
# 5          0
# 11         0
# 12         0
#           ..
# 6153229    0
# 6153231    0
# 6153232    0
# 6153234    0
# 6153235    0
# Name: Class, Length: 4312408, dtype: int64

# %%
df3=df2.copy()

# %%
df3.Class=df3.Class.apply(lambda x:1 if x=='FA' else 0)

# %%
df3
# Out:
#                                               Article Name Importance  \
# 3                                         Wilbur_E._Colyer        NaN
# 4                                              Salmson_B.9        NaN
# 5        Campaign_to_Suppress_Bandits_in_northeastern_G...        NaN
# 11                                            Wilfred_Cass        NaN
# 12                                       Șimian,_Mehedinți        NaN
# ...                                                    ...        ...
# 6153229                                        Out_of_Life        NaN
# 6153231                                          Thamserku        NaN
# 6153232                                   I_Wanna_Hold_You        NaN
# 6153234             China_and_the_World_Trade_Organization        NaN
# 6153235                             Jan_de_Vries_(athlete)        NaN
#
#                                                      Topic  Class Level
# 3        ['biography', 'military history', 'united stat...      0   NaN
# 4                                                      NaN      0   NaN
# 5                                                      NaN      0   NaN
# 11                                                     NaN      0   NaN
# 12                                             ['romania']      0   NaN
# ...                                                    ...    ...   ...
# 6153229                                                NaN      0   NaN
# 6153231                             ['mountains', 'nepal']      0   NaN
# 6153232                                                 []      0   NaN
# 6153234                                          ['china']      0   NaN
# 6153235  ['running', 'olympics', 'biography', 'netherla...      0   NaN
#
# [4312408 rows x 5 columns]

# %%
df3[df2.Class=="FA"]
# Out:
#                                  Article Name   Importance  \
# 1118                       History_of_biology      History
# 2394                                 Canberra   Geography
# 2402                     Edward_II_of_England       People
# 2629                                      MTR   Technology
# 3078                                  CM_Punk          NaN
# ...                                       ...          ...
# 6149122                      Romeo_and_Juliet          Art
# 6152007                       Columbia_Slough          NaN
# 6152395  Somerset_County_Cricket_Club_in_2009          NaN
# 6152825                   Maya_(M.I.A._album)          NaN
# 6153098                            Alcibiades       People
#
#                                                      Topic  Class Level
# 1118     ['history of science', 'biology', 'palaeontolo...      1     4
# 2394                               ['australia', 'cities']      1    4
# 2402     ['biography', 'military history', 'england', '...      1     5
# 2629                                                    []      1     5
# 3078     ['biography', 'professional wrestling', 'mixed...      1   NaN
# ...                                                    ...    ...   ...
# 6149122  ['banner shell', 'theatre', 'elizabethan theat...      1     4
# 6152007                                         ['oregon']      1   NaN
# 6152395                                       ['somerset']      1   NaN
# 6152825          ['albums', 'electronic music', 'hip hop']      1   NaN
# 6153098  ['biography', 'classical greece and rome', 'gr...      1     4
#
# [5386 rows x 5 columns]

# %%
df4=df3[["Article Name","Class"]]

# %%
df4
# Out:
#                                               Article Name  Class
# 3                                         Wilbur_E._Colyer      0
# 4                                              Salmson_B.9      0
# 5        Campaign_to_Suppress_Bandits_in_northeastern_G...      0
# 11                                            Wilfred_Cass      0
# 12                                       Șimian,_Mehedinți      0
# ...                                                    ...    ...
# 6153229                                        Out_of_Life      0
# 6153231                                          Thamserku      0
# 6153232                                   I_Wanna_Hold_You      0
# 6153234             China_and_the_World_Trade_Organization      0
# 6153235                             Jan_de_Vries_(athlete)      0
#
# [4312408 rows x 2 columns]

# %%
df4.nunique()
# Out:
# Article Name    4312407
# Class                 2
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4312408 entries, 3 to 6153235
# Data columns (total 2 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Article Name  object
#  1   Class         int64
# dtypes: int64(1), object(1)
# memory usage: 98.7+ MB

# %%
df5=df4[~df4["Article Name"].isnull()]

# %%
feature=df5[df5["Class"]==1].head(456)

# %%
nonfeature=df5[df5["Class"]==0].head(632)

# %%
df6=pd.concat([feature,nonfeature])

# %%
df6
# Out:
#                Article Name  Class
# 1118     History_of_biology      1
# 2394               Canberra      1
# 2402   Edward_II_of_England      1
# 2629                    MTR      1
# 3078                CM_Punk      1
# ...                     ...    ...
# 889            Oulad_Ouchih      0
# 890         Slovenská_Kajňa      0
# 891             Streetnoise      0
# 892    Micropholis_maguirei      0
# 896   Portrait_Professional      0
#
# [1088 rows x 2 columns]

# %%
# !pip install Wikipedia-API
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Wikipedia-API
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from Wikipedia-API) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->Wikipedia-API) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->Wikipedia-API) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->Wikipedia-API) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->Wikipedia-API) (2.10)
# Installing collected packages: Wikipedia-API
# Successfully installed Wikipedia-API-0.5.8

# %%
import wikipediaapi

wiki = wikipediaapi.Wikipedia(language='en', extract_format=wikipediaapi.ExtractFormat.WIKI)

page_title = "Python (programming language)"
page = wiki.page(page_title)

# %%
import re

# 1. Number of words in the last revision
text = page.text
words = len(text.split())
print("Number of words in the last revision: ", words)

# 2. Total number of revisions
import requests

url = page.fullurl
html = requests.get(url).content
match = re.search(r'About (\d+)', html.decode())
if match:
    total_revisions = match.group(1)
    print("Total number of revisions: ", total_revisions)
else:
    print("No match found")

# 3. Number of distinct users
users = set()
match = re.findall(r'<a href="/wiki/User:(.*?)"', html.decode())
for user in match:
    users.add(user)
print("Number of distinct users: ", len(users))

# 4. Number of Wikilinks in the last revision
wikilinks = len(re.findall(r'\[\[(.*?)\]\]', text))
print("Number of Wikilinks in the last revision: ", wikilinks)
# Out:
# Number of words in the last revision:  5900
# No match found
# Number of distinct users:  0
# Number of Wikilinks in the last revision:  0

# %%
def numofword(title):
  page_title = title
  page = wiki.page(page_title)
  text = page.text
  words = len(text.split())
  return words

# %%
numofword("Micropholis_maguirei")
# Out:
# 21

# %%
num_word=df6["Article Name"].apply(numofword)

# %%
num_word
# Out:
# 1118     7295
# 2394     9818
# 2402    11970
# 2629     9764
# 3078    10948
#         ...
# 889        42
# 890       195
# 891       454
# 892        21
# 896       630
# Name: Article Name, Length: 1088, dtype: int64

# %%
df7=df6.copy()

# %%
df7["num_word"]=num_word

# %%
df7
# Out:
#                Article Name  Class  num_word
# 1118     History_of_biology      1      7295
# 2394               Canberra      1      9818
# 2402   Edward_II_of_England      1     11970
# 2629                    MTR      1      9764
# 3078                CM_Punk      1     10948
# ...                     ...    ...       ...
# 889            Oulad_Ouchih      0        42
# 890         Slovenská_Kajňa      0       195
# 891             Streetnoise      0       454
# 892    Micropholis_maguirei      0        21
# 896   Portrait_Professional      0       630
#
# [1088 rows x 3 columns]

# %%
def numofrevisions(title):
  url = page.fullurl
  html = requests.get(url).content
  match = re.search(r'About (\d+)', html.decode())
  if match:
      total_revisions = match.group(1)
      print("Total number of revisions: ", total_revisions)
  else:
      print("No match found")

# %%
print(numofrevisions("Edward_II_of_England"))
# Out:
# No match found
# None

# %%
def numusers(title):
  page_title = title
  page = wiki.page(page_title)
  users = set()
  match = re.findall(r'<a href="/wiki/User:(.*?)"', html.decode())
  for user in match:
      users.add(user)
  return len(users)

# %%
numusers("Edward_II_of_England")
# Out:
# 0

# %%
def numofWikilinks(title):
  page_title = title
  page = wiki.page(page_title)
  wikilinks = len(re.findall(r'\[\[(.*?)\]\]', text))
  return wikilinks

# %%
numofWikilinks("Edward_II_of_England")
# Out:
# 0

# %%
numof_use=df6["Article Name"].apply(numusers)

# %%
numof_use.unique()
# Out:
# array([0])

# %%
def numofword(title):
  page_title = title
  page = wiki.page(page_title)
  text = page.text

# %%
import requests
def numrevision(TITLE):
  BASE_URL = "http://en.wikipedia.org/w/api.php"


  parameters = { 'action': 'query',
            'format': 'json',
            'continue': '',
            'titles': TITLE,
            'prop': 'revisions',
            'rvprop': 'ids|userid',
            'rvlimit': 'max'}

  wp_call = requests.get(BASE_URL, params=parameters)
  response = wp_call.json()

  total_revisions = 0

  while True:
    wp_call = requests.get(BASE_URL, params=parameters)
    response = wp_call.json()

    for page_id in response['query']['pages']:
      try:
        total_revisions += len(response['query']['pages'][page_id]['revisions'])
      except KeyError:
        return 0

    if 'continue' in response:
      parameters['continue'] = response['continue']['continue']
      parameters['rvcontinue'] = response['continue']['rvcontinue']

    else:
      break

  return total_revisions

# %%
numrevision("History_of_biology")
# Out:
# 1251

# %%
lis=[]
f=1
for i in df6["Article Name"]:
  n=numrevision(i)
  print(f,n)
  lis.append(n)
  f=f+1
# Out:
# 1 1251
# 2 5097
# 3 3032
# 4 3960
# 5 14206
# 6 899
# 7 1304
# 8 1187
# 9 574
# 10 211
# 11 3535
# 12 412
# 13 3874
# 14 831
# 15 8035
# 16 140
# 17 111
# 18 1193
# 19 2139
# 20 774
# 21 31
# 22 1275
# 23 2588
# 24 9042
# 25 400
# 26 2407
# 27 11902
# 28 474
# 29 1053
# 30 1190
# 31 4703
# 32 898
# 33 161
# 34 675
# 35 527
# 36 1125
# 37 2589
# 38 102
# 39 91
# 40 1975
# 41 1261
# 42 1619
# 43 113
# 44 433
# 45 322
# 46 6503
# 47 445
# 48 8361
# 49 2063
# 50 373
# 51 1060
# 52 97
# 53 857
# 54 433
# 55 569
# 56 2224
# 57 1676
# 58 1084
# 59 187
# 60 962
# 61 7
# 62 565
# 63 374
# 64 344
# 65 1151
# 66 922
# 67 1422
# 68 461
# 69 433
# 70 103
# 71 1188
# 72 3513
# 73 2057
# 74 525
# 75 8752
# 76 285
# 77 3981
# 78 1504
# 79 302
# 80 134
# 81 195
# 82 804
# 83 996
# 84 3901
# 85 14440
# 86 2724
# 87 1279
# 88 1
# 89 844
# 90 1632
# 91 1634
# 92 234
# 93 514
# 94 526
# 95 283
# 96 4
# 97 193
# 98 669
# 99 392
# 100 700
# 101 643
# 102 590
# 103 278
# 104 5526
# 105 897
# 106 2143
# 107 6816
# 108 1139
# 109 250
# 110 517
# 111 228
# 112 356
# 113 378
# 114 937
# 115 547
# 116 20571
# 117 506
# 118 464
# 119 12197
# 120 523
# 121 7971
# 122 9432
# 123 734
# 124 665
# 125 1075
# 126 230
# 127 1206
# 128 548
# 129 281
# 130 1072
# 131 1098
# 132 3438
# 133 1206
# 134 852
# 135 781
# 136 1692
# 137 297
# 138 5215
# 139 227
# 140 232
# 141 527
# 142 771
# 143 808
# 144 1028
# 145 2
# 146 4445
# 147 818
# 148 268
# 149 499
# 150 233
# 151 220
# 152 248
# 153 239
# 154 539
# 155 506
# 156 113
# 157 855
# 158 483
# 159 601
# 160 13888
# 161 570
# 162 809
# 920 49
# 921 0
# 922 294
# 923 1
# 924 17
# 925 12
# 926 9
# 927 329
# 928 1
# 929 72
# 930 5
# 931 67
# 932 152
# 933 39
# 934 21
# 935 31
# 936 23
# 937 17
# 938 18
# 939 71
# 940 36
# 941 29
# 942 17
# 943 44
# 944 1256
# 945 30
# 946 83
# 947 29
# 948 16
# 949 66
# 950 32
# 951 8
# 952 100
# 953 18
# 954 198
# 955 96
# 956 360
# 957 35
# 958 26
# 959 9
# 960 43
# 961 27
# 962 128
# 963 35
# 964 79
# 965 87
# 966 101
# 967 1601
# 968 26
# 969 31
# 970 152
# 971 50
# 972 8
# 973 85
# 974 94
# 975 38
# 976 19
# 977 2
# 978 72
# 979 40
# 980 24
# 981 53
# 982 33
# 983 25
# 984 122
# 985 42
# 986 17
# 987 212
# 988 0
# 989 163
# 990 103
# 991 83
# 992 715
# 993 32
# 994 15
# 995 409
# 996 40
# 997 61
# 998 14
# 999 16
# 1000 186
# 1001 42
# 1002 25
# 1003 77
# 1004 26
# 1005 29
# 1006 19
# 1007 64
# 1008 99
# 1009 49
# 1010 59
# 1011 61
# 1012 74
# 1013 34
# 1014 23
# 1015 8
# 1016 31
# 1017 14
# 1018 230
# 1019 16
# 1020 48
# 1021 72
# 1022 62
# 1023 65
# 1024 1
# 1025 14
# 1026 714
# 1027 34
# 1028 126
# 1029 73
# 1030 52
# 1031 39
# 1032 120
# 1033 61
# 1034 3
# 1035 62
# 1036 32
# 1037 176
# 1038 553
# 1039 252
# 1040 18
# 1041 137
# 1042 79
# 1043 352
# 1044 200
# 1045 1
# 1046 30
# 1047 1280
# 1048 65
# 1049 168
# 1050 203
# 1051 20
# 1052 896
# 1053 67
# 1054 95
# 1055 39
# 1056 30
# 1057 32
# 1058 16
# 1059 81
# 1060 9
# 1061 496
# 1062 46
# 1063 151
# 1064 194
# 1065 2
# 1066 170
# 1067 75
# 1068 321
# 1069 601
# 1070 14
# 1071 0
# 1072 2
# 1073 99
# 1074 74
# 1075 5
# 1076 970
# 1077 16
# 1078 271
# 1079 77
# 1080 88
# 1081 90
# 1082 25
# 1083 64
# 1084 7
# 1085 61
# 1086 108
# 1087 29
# 1088 192

# %%
df7["num_of_revisions"]=lis

# %%
df7.to_csv('file1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6cb6042337db> in <module>
# ----> 1 df7.to_csv('file1.csv')
#
# NameError: name 'df7' is not defined

# %%
df7=pd.read_csv("/content/file1.csv")

# %%
df7.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
sns.scatterplot(data=df7,x="num_word",y="num_of_revisions",hue="Class")

# %%
sns.boxplot(df7.num_word[df7["Class"]==0])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df7.num_word[df7["Class"]==1])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df7.num_of_revisions[df7["Class"]==0])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df7.num_of_revisions[df7["Class"]==1])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df7.drop(["Class","Article Name"],axis=1), df7["Class"], test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       num_word  num_of_revisions
# 834        100                30
# 552        184                71
# 855        590               229
# 215       8110              6889
# 256       4317              1178
# ...        ...               ...
# 330       8857              4108
# 466         94                12
# 121      12795              9432
# 1044      1329                 1
# 860        440               100
#
# [870 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Create an instance of the StandardScaler
scaler = StandardScaler()

# Fit the scaler to your data
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import numpy as np


model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [0.1, 1, 10],
            'kernel': ['rbf','linear']
        }  
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params' : {
            'max_depth': [3, 5, 7, None],
            'min_samples_split': [2, 5, 10]
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [10, 50, 100, 200],
            'max_depth': [3, 5, 7, None],
            'min_samples_split': [2, 5, 10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': np.logspace(-3, 3, 7),
            'penalty': ['l1', 'l2']
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.934483
# 1        decision_tree    0.924138
# 2        random_forest    0.933333
# 3  logistic_regression    0.920690
#
#                                          best_params
# 0                          {'C': 1, 'kernel': 'rbf'}
# 1           {'max_depth': 5, 'min_samples_split': 2}
# 2  {'max_depth': None, 'min_samples_split': 2, 'n...
# 3                       {'C': 10.0, 'penalty': 'l1'}

# %%
from sklearn.model_selection import GridSearchCV

# %%
model=svm.SVC(gamma='auto',C=1,kernel="rbf")

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma='auto')

# %%
model.score(X_test,y_test)
# Out:
# 0.926605504587156

# %% [markdown]
# ###accuracy getting 92.66%

# %%
from sklearn.metrics import confusion_matrix
y_pred=model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[109,  12],
#        [  4,  93]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(7,5))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(42.0, 0.5, 'Truth')

# %%
import pickle
with open('model_pickles_wiki','wb') as file:
    pickle.dump(model,file)

# %%
model.predict([[20,23]])
# Out:
# array([1])

# %%
model1=DecisionTreeClassifier(max_depth=5,min_samples_split=2)

# %%
model1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
model1.feature_importances_
# Out:
# array([0.93673879, 0.06326121])

# %% [markdown]
# ### Number of words in the last revision this is most important feature we can also predict use only Number of words in the last revision

# %%
X_test
# Out:
# array([[ 1.24947455e-01, -6.99325950e-03],
#        [ 1.44328996e+00,  2.84184040e-01],
#        [-7.05096501e-01, -3.60537320e-01],
#        [-4.68258987e-01, -3.62920763e-01],
#        [-7.10500847e-01, -3.64509725e-01],
#        [ 2.84015444e+00,  1.26479554e-01],
#        [-6.93652003e-01, -3.21210509e-01],
#        [ 2.09149357e+00,  2.69486141e-01],
#        [-7.63590598e-01, -3.78413143e-01],
#        [-7.56278836e-01, -3.69276612e-01],
#        [-4.58404004e-01, -2.43748608e-01],
#        [ 4.76229941e-01, -2.89431268e-01],
#        [-7.28621301e-01, -3.60140080e-01],
#        [-7.20355830e-01, -3.74837979e-01],
#        [ 2.76587044e-01, -3.91697414e-02],
#        [ 3.16642784e-01,  5.55896554e-01],
#        [-4.36468717e-01, -3.04923648e-01],
#        [-7.26078079e-01, -3.72057295e-01],
#        [-1.20155528e-01, -3.14854661e-01],
#        [-7.50874490e-01, -3.48620105e-01],
#        [-4.67941085e-01, -3.52195269e-01],
#        [-6.20216479e-01, -3.41867016e-01],
#        [ 4.54717794e-02, -2.87445065e-01],
#        [ 6.88271043e-01, -7.61131096e-02],
#        [ 4.39989033e-01, -8.84275656e-02],
#        [-6.76167355e-01, -3.43058737e-01],
